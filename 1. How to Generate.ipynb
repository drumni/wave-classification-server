# %%
from Classification import Classification

# %%
cation = Classification()
cation.loadAudioLibrary('D:/Emotion Test/')
# Out:
# Basement	█▍                   203/2900 [00:11 -> 49:46]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File D:\Devtools\miniconda\lib\site-packages\librosa\core\audio.py:155, in load(path, sr, mono, offset, duration, dtype, res_type)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=152'>153</a> else:
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=153'>154</a>     # Otherwise, create the soundfile object
# --> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=154'>155</a>     context = sf.SoundFile(path)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=156'>157</a> with context as sf_desc:
#
# File D:\Devtools\miniconda\lib\site-packages\soundfile.py:629, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=626'>627</a> self._info = _create_info_struct(file, mode, samplerate, channels,
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=627'>628</a>                                  format, subtype, endian)
# --> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=628'>629</a> self._file = self._open(file, mode_int, closefd)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=629'>630</a> if set(mode).issuperset('r+') and self.seekable():
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=630'>631</a>     # Move write position to 0 (like in Python file objects)
#
# File D:\Devtools\miniconda\lib\site-packages\soundfile.py:1183, in SoundFile._open(self, file, mode_int, closefd)
#    <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=1181'>1182</a>     raise TypeError("Invalid file: {0!r}".format(self.name))
# -> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=1182'>1183</a> _error_check(_snd.sf_error(file_ptr),
#    <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=1183'>1184</a>              "Error opening {0!r}: ".format(self.name))
#    <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=1184'>1185</a> if mode_int == _snd.SFM_WRITE:
#    <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=1185'>1186</a>     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=1186'>1187</a>     # when opening a named pipe in SFM_WRITE mode.
#    <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=1187'>1188</a>     # See http://github.com/erikd/libsndfile/issues/77.
#
# File D:\Devtools\miniconda\lib\site-packages\soundfile.py:1357, in _error_check(err, prefix)
#    <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=1355'>1356</a> err_str = _snd.sf_error_number(err)
# -> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/soundfile.py?line=1356'>1357</a> raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#
# RuntimeError: Error opening 'D:/Emotion Test/Basement/Game of Thrones (Drum & Bass Remix)_304678641 - SinisterCheese.mp3': Format not recognised.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\robin\.mega\Coding\Python\Genre-Classification\1. How to Generate.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/1.%20How%20to%20Generate.ipynb#ch0000001?line=0'>1</a> cation = Classification()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/1.%20How%20to%20Generate.ipynb#ch0000001?line=1'>2</a> cation.loadAudioLibrary('D:/Emotion Test/')
#
# File c:\Users\robin\.mega\Coding\Python\Genre-Classification\Classification.py:26, in Classification.loadAudioLibrary(self, path)
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=22'>23</a> self.labels = os.listdir(path)
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=23'>24</a> for dir in self.labels:
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=24'>25</a>     # print(f'Loading Folder {dir}:')
# ---> <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=25'>26</a>     self.loadFolder(dir)
#
# File c:\Users\robin\.mega\Coding\Python\Genre-Classification\Classification.py:41, in Classification.loadFolder(self, label)
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=37'>38</a> filename = os.path.basename(file_path).replace(' ', '_')
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=38'>39</a> if self.validateFile(file_path, filename):
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=39'>40</a>     # print(f'    Loading file: {file_path}')
# ---> <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=40'>41</a>     if results := self.loadFile(file_path, progress_bar):
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=41'>42</a>         for i, result in enumerate(results):
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=42'>43</a>             result['filename'] = self.getFilename(filename, i)
#
# File c:\Users\robin\.mega\Coding\Python\Genre-Classification\Classification.py:55, in Classification.loadFile(self, file_path, progress_bar)
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=52'>53</a> if(alyis.failed == True):
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=53'>54</a>     return False
# ---> <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/Classification.py?line=54'>55</a> return alyis.calculate()
#
# File c:\Users\robin\.mega\Coding\Python\Genre-Classification\src\analysis.py:30, in Analysis.calculate(self)
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/analysis.py?line=26'>27</a> self.length = librosa.get_duration(filename=self.audio_path, sr=sr) / 60 # self.duration = len(self.audio_data) / SAMPLE_RATE / 60
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/analysis.py?line=27'>28</a> self.offset_per_segment = self.segment_duration / self.segment_count # self.frames = SAMPLE_RATE * self.duration # self.samples_per_second = self.frames / segment_count
# ---> <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/analysis.py?line=29'>30</a> self.addFeatures()
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/analysis.py?line=31'>32</a> return [segment.features for segment in self.segments]
#
# File c:\Users\robin\.mega\Coding\Python\Genre-Classification\src\analysis.py:40, in Analysis.addFeatures(self)
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/analysis.py?line=36'>37</a> offset = self.offset_per_segment
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/analysis.py?line=38'>39</a> segment = Segment()
# ---> <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/analysis.py?line=39'>40</a> segment.load(self.audio_path,  offset * i, self.segment_duration, target_sr=self.rate)
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/analysis.py?line=41'>42</a> segment.addFeatures()
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/analysis.py?line=43'>44</a> self.segments.append(segment)
#
# File c:\Users\robin\.mega\Coding\Python\Genre-Classification\src\segment.py:14, in Segment.load(self, path, offset, length, target_sr)
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/segment.py?line=11'>12</a> def load(self, path, offset, length, target_sr):
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/segment.py?line=12'>13</a>     # TODO add  random offset by seed
# ---> <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/segment.py?line=13'>14</a>     self.audio_data, self.rate = librosa.load(
#      <a href='file:///c%3A/Users/robin/.mega/Coding/Python/Genre-Classification/src/segment.py?line=14'>15</a>         path, offset=offset, duration=length, sr=target_sr)
#
# File D:\Devtools\miniconda\lib\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/util/decorators.py?line=85'>86</a> extra_args = len(args) - len(all_args)
#      <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/util/decorators.py?line=86'>87</a> if extra_args <= 0:
# ---> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/util/decorators.py?line=87'>88</a>     return f(*args, **kwargs)
#      <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/util/decorators.py?line=89'>90</a> # extra_args > 0
#      <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/util/decorators.py?line=90'>91</a> args_msg = [
#      <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/util/decorators.py?line=91'>92</a>     "{}={}".format(name, arg)
#      <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/util/decorators.py?line=92'>93</a>     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/util/decorators.py?line=93'>94</a> ]
#
# File D:\Devtools\miniconda\lib\site-packages\librosa\core\audio.py:174, in load(path, sr, mono, offset, duration, dtype, res_type)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=171'>172</a> if isinstance(path, (str, pathlib.PurePath)):
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=172'>173</a>     warnings.warn("PySoundFile failed. Trying audioread instead.", stacklevel=2)
# --> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=173'>174</a>     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=174'>175</a> else:
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=175'>176</a>     raise (exc)
#
# File D:\Devtools\miniconda\lib\site-packages\librosa\core\audio.py:198, in __audioread_load(path, offset, duration, dtype)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=191'>192</a> """Load an audio buffer using audioread.
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=192'>193</a>
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=193'>194</a> This loads one block at a time, and then concatenates the results.
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=194'>195</a> """
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=196'>197</a> y = []
# --> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=197'>198</a> with audioread.audio_open(path) as input_file:
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=198'>199</a>     sr_native = input_file.samplerate
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/librosa/core/audio.py?line=199'>200</a>     n_channels = input_file.channels
#
# File D:\Devtools\miniconda\lib\site-packages\audioread\__init__.py:111, in audio_open(path, backends)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/__init__.py?line=108'>109</a> for BackendClass in backends:
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/__init__.py?line=109'>110</a>     try:
# --> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/__init__.py?line=110'>111</a>         return BackendClass(path)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/__init__.py?line=111'>112</a>     except DecodeError:
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/__init__.py?line=112'>113</a>         pass
#
# File D:\Devtools\miniconda\lib\site-packages\audioread\ffdec.py:174, in FFmpegAudioFile.__init__(self, filename, block_size)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=170'>171</a> self.stdout_reader.start()
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=172'>173</a> # Read relevant information from stderr.
# --> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=173'>174</a> self._get_info()
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=175'>176</a> # Start a separate thread to read the rest of the data from
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=176'>177</a> # stderr. This (a) avoids filling up the OS buffer and (b)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=177'>178</a> # collects the error output for diagnosis.
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=178'>179</a> self.stderr_reader = QueueReaderThread(self.proc.stderr)
#
# File D:\Devtools\miniconda\lib\site-packages\audioread\ffdec.py:218, in FFmpegAudioFile._get_info(self)
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=215'>216</a> out_parts = []
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=216'>217</a> while True:
# --> <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=217'>218</a>     line = self.proc.stderr.readline()
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=218'>219</a>     if not line:
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=219'>220</a>         # EOF and data not found.
#     <a href='file:///d%3A/Devtools/miniconda/lib/site-packages/audioread/ffdec.py?line=220'>221</a>         raise CommunicationError("stream info not found")
#
# KeyboardInterrupt:
