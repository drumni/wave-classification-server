# %%
from src.core.Generation import Generation

# %%
cation = Generation(data_dir='DnB', segments = 10, tracks = 200, seconds = 3)
cation.loadAudioLibrary('D:/Emotion Test/')
# Out:
# Data Directory: data\s-3
#                                             filename  chroma_stft10_mean  \
# 0  IMANU_&_The_Caracal_Project_-_La_Fournaise_(Ft...           -0.033913
# 1  IMANU_&_The_Caracal_Project_-_La_Fournaise_(Ft...            0.010932
# 2  IMANU_&_The_Caracal_Project_-_La_Fournaise_(Ft...           -0.006109
# 3  IMANU_&_The_Caracal_Project_-_La_Fournaise_(Ft...            0.012207
# 4  IMANU_&_The_Caracal_Project_-_La_Fournaise_(Ft...           -0.021020
#
#    chroma_stft10_var  chroma_stft11_mean  chroma_stft11_var  \
# 0           0.300687           -0.001690           0.257994
# 1           0.313467           -0.000910           0.303425
# 2           0.340042            0.012635           0.341623
# 3           0.475078           -0.021291           0.486525
# 4           0.465074           -0.024162           0.416776
#
#    chroma_stft12_mean  chroma_stft12_var  chroma_stft1_mean  chroma_stft1_var  \
# ...
